# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 연습 문제 1¶
# 1. 임의로 두 개의 시리즈 객체를 만든다. 모두 문자열 인덱스를 가져야 하며 두 시리즈에 공통적으로 포함되지 않는 라벨이 있어야 한다.
#
# 2. 위에서 만든 두 시리즈 객체를 이용하여 사칙 연산을 한다.

# %%
score_2015 = pd.Series([80,90,72,78], index=['국어', '수학', '영어', '과학'])
score_2016 = pd.Series([90,76,89,80], index= ['국어', '수학', '영어', '사회'])

# %%
score = score_2016 - score_2015
score
# Out:
# 과학     NaN
# 국어    10.0
# 사회     NaN
# 수학   -14.0
# 영어    17.0
# dtype: float64

# %%
rate_score = (score_2016-score_2015) / score_2015 * 100
rate_score = rate_score[rate_score.notnull()]
rate_score
# Out:
# 국어    12.500000
# 수학   -15.555556
# 영어    23.611111
# dtype: float64

# %%
s1 = score_2016 + score_2015
s1
# Out:
# 과학      NaN
# 국어    170.0
# 사회      NaN
# 수학    166.0
# 영어    161.0
# dtype: float64

# %%
s1/2
# Out:
# 과학     NaN
# 국어    85.0
# 사회     NaN
# 수학    83.0
# 영어    80.5
# dtype: float64

# %%
s2 = score_2016 * score_2015

# %%
s2
# Out:
# 과학       NaN
# 국어    7200.0
# 사회       NaN
# 수학    6840.0
# 영어    6408.0
# dtype: float64

# %%
score_2016
# Out:
# 국어    90
# 수학    76
# 영어    89
# 사회    80
# dtype: int64

# %%
score_2016["과학"] = 91

# %%
score_2016
# Out:
# 국어    90
# 수학    76
# 영어    89
# 사회    80
# 과학    91
# dtype: int64

# %% [markdown]
# 연습 문제 2¶
#
# 다음 조건을 만족하는 임의의 데이터프레임을 하나 만든다.
#
# 1. 열의 갯수와 행의 갯수가 각각 5개 이상이어야 한다.
# 2. 열에는 정수, 문자열, 실수 자료형 데이터가 각각 1개 이상씩 포함되어 있어야 한다.

# %%
data = {
    "2018": [91, 99, 91, 92, 9.1],
    "2017": [87, 95, 85, 95, 8.4],
    "2016": [84, 85, 87, 93, 7.0],
    "2015": [83, 80, 83, 93, 7.3],
    "2014": [83, 78, 79, 91, 7.1],
    "시험장소": ['우리반',' 우리반', '우리반', '체육관', '음악실']
}
columns = ["시험장소", "2014", "2015", "2016", "2017", "2018"]
index = ["국어", "영어", "수학", "체육", "음악수행"]
df = pd.DataFrame(data, index= index, columns=columns).T
df
# Out:
#        국어    영어   수학   체육 음악수행
# 시험장소  우리반   우리반  우리반  체육관  음악실
# 2014   83    78   79   91  7.1
# 2015   83    80   83   93  7.3
# 2016   84    85   87   93    7
# 2017   87    95   85   95  8.4
# 2018   91    99   91   92  9.1

# %% [markdown]
# 연습 문제 3¶
# 다음 데이터프레임에서 지정하는 데이터를 뽑아내거나 처리하라.
#
# data = {
#     "국어": [80, 90, 70, 30],
#     "영어": [90, 70, 60, 40],
#     "수학": [90, 60, 80, 70],
# }
# columns = ["국어", "영어", "수학"]
# index = ["춘향", "몽룡", "향단", "방자"]
# df = pd.DataFrame(data, index=index, columns=columns)
#
# 1. 모든 학생의 수학 점수를 시리즈로 나타낸다.
# 2. 모든 학생의 국어와 영어 점수를 데이터 프레임으로 나타낸다.
# 3. 모든 학생의 각 과목 평균 점수를 새로운 열로 추가한다.
# 4. 방자의 영어 점수를 80점으로 수정하고 평균 점수도 다시 계산한다.
# 5. 춘향의 점수를 데이터프레임으로 나타낸다.
# 6. 향단의 점수를 시리즈로 나타낸다.

# %%
data = {
    "국어": [80, 90, 70, 30],
    "영어": [90, 70, 60, 40],
    "수학": [90, 60, 80, 70],
}
columns = ["국어", "영어", "수학"]
index = ["춘향", "몽룡", "향단", "방자"]
df = pd.DataFrame(data, index=index, columns=columns)

# %%
df["수학"]
# Out:
# 춘향    90
# 몽룡    60
# 향단    80
# 방자    70
# Name: 수학, dtype: int64

# %%
type(df["수학"])
# Out:
# pandas.core.series.Series

# %%
df[["국어", "영어"]]
# Out:
#     국어  영어
# 춘향  80  90
# 몽룡  90  70
# 향단  70  60
# 방자  30  40

# %%
type(df[["국어", "영어"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df["평균점수"]= (df["국어"] + df["영어"] + df["수학"])/3
df

# %%
df
# Out:
#     국어  영어  수학       평균점수
# 춘향  80  90  90  86.666667
# 몽룡  90  70  60  73.333333
# 향단  70  60  80  70.000000
# 방자  30  40  70  46.666667

# %%
df["영어"]["방자"] = 80
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df["평균점수"]= (df["국어"] + df["영어"] + df["수학"])/3
df
# Out:
#     국어  영어  수학       평균점수
# 춘향  80  90  90  86.666667
# 몽룡  90  70  60  73.333333
# 향단  70  60  80  70.000000
# 방자  30  80  70  60.000000

# %%
df["춘향":"춘향"]
# Out:
#     국어  영어  수학       평균점수
# 춘향  80  90  90  86.666667

# %%
type(df["춘향":"춘향"])
# Out:
# pandas.core.frame.DataFrame

# %%
df.T
# Out:
#              춘향         몽룡    향단    방자
# 국어    80.000000  90.000000  70.0  30.0
# 영어    90.000000  70.000000  60.0  80.0
# 수학    90.000000  60.000000  80.0  70.0
# 평균점수  86.666667  73.333333  70.0  60.0

# %%
df.T['향단']
# Out:
# 국어      70.0
# 영어      60.0
# 수학      80.0
# 평균점수    70.0
# Name: 향단, dtype: float64

# %%
type(df.T['향단'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# 연습 문제 1¶
# 1. 모든 행과 열에 라벨을 가지는 5 x 5 이상의 크기를 가지는 데이터프레임을 만든다.
# 2. 10가지 이상의 방법으로 특정한 행과 열을 선택한다.
# -> "C"열 또는 "c"행 또는 "c,C"셀만 선택하겠음

# %%
df = pd.DataFrame(np.arange(10,35).reshape(5,5),
             index = ["a", "b", "c", "d", "e"],
             columns = ["A", "B", "C", "D", "E"])
df
# Out:
#     A   B   C   D   E
# a  10  11  12  13  14
# b  15  16  17  18  19
# c  20  21  22  23  24
# d  25  26  27  28  29
# e  30  31  32  33  34

# %%
df["C"]["c"]
# Out:
# 22

# %%
df.loc["c", "C"]
# Out:
# 22

# %%
df.loc["c":"c", "C":"C"]
# Out:
#     C
# c  22

# %%
df.iloc[2,2]
# Out:
# 22

# %%
df["C"]
# Out:
# a    12
# b    17
# c    22
# d    27
# e    32
# Name: C, dtype: int32

# %%
df.loc[:, "C"]
# Out:
# a    12
# b    17
# c    22
# d    27
# e    32
# Name: C, dtype: int32

# %%
df.iloc[:,2]
# Out:
# a    12
# b    17
# c    22
# d    27
# e    32
# Name: C, dtype: int32

# %%
df.iloc[:, -3]
# Out:
# a    12
# b    17
# c    22
# d    27
# e    32
# Name: C, dtype: int32

# %%
df.loc["c"]
# Out:
# A    20
# B    21
# C    22
# D    23
# E    24
# Name: c, dtype: int32

# %%
df.loc["c", :]
# Out:
# A    20
# B    21
# C    22
# D    23
# E    24
# Name: c, dtype: int32

# %%
df.iloc[2]
# Out:
# A    20
# B    21
# C    22
# D    23
# E    24
# Name: c, dtype: int32

# %%
df.iloc[-3]
# Out:
# A    20
# B    21
# C    22
# D    23
# E    24
# Name: c, dtype: int32

# %%
df["c":"c"]
# Out:
#     A   B   C   D   E
# c  20  21  22  23  24

# %%
df.loc["c":"c"]
# Out:
#     A   B   C   D   E
# c  20  21  22  23  24

# %%
df.loc[["c"]]
# Out:
#     A   B   C   D   E
# c  20  21  22  23  24

# %%
df.loc[(df.A > 18) & (df.A <23)]
# Out:
#     A   B   C   D   E
# c  20  21  22  23  24

# %%
df.iloc[[2]]
# Out:
#     A   B   C   D   E
# c  20  21  22  23  24

# %%
df.iloc[[-3]]
# Out:
#     A   B   C   D   E
# c  20  21  22  23  24

# %% [markdown]
# 연습 문제 4.2.5¶
# 다음 명령으로 타이타닉호 승객 데이터를 데이터프레임으로 읽어온다.
#
# 이 명령을 실행하려면 seaborn 패키지가 설치되어 있어야 한다.
#
# import seaborn as sns
# titanic = sns.load_dataset("titanic")
#
# 타이타닉호 승객 데이터의 데이터 값을 각 열마다 구해본다.

# %%
import seaborn as sns 
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
titanic.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %% [markdown]
# 연습 문제 4.2.6¶
# 타이타닉호 승객중 성별(sex) 인원수, 나이별(age) 인원수,
#
# 선실별(class) 인원수, 사망/생존(alive) 인원수를 구하라.

# %%
titanic["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
titanic["age"].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: age, Length: 88, dtype: int64

# %%
titanic["class"].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
titanic["alive"].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %% [markdown]
# 연습 문제 4.2.7¶
#
# bins = [1, 15, 25, 35, 60, 99]
# labels = ["미성년자", "청년", "중년", "장년", "노년"]
#
# 타이타닉호 승객을 사망자와 생존자 그룹으로 나누고 각 그룹에 대해
#
# '미성년자', '청년', '중년', '장년', '노년' 승객의 비율을 구한다.
#
# 각 그룹 별로 비율의 전체 합은 1이 되어야 한다.
#
# 뒤의 노트에 작성~
